# %%
def quick_sort(A, low, high):
    if low < high:
        p = partition(A, low, high)
        quick_sort(A, low, p-1)
        quick_sort(A, p+1, high)

def partition(A, low, high):
    pivot = A[high]
    i = low - 1
    for j in range(low, high):
        if A[j] <= pivot:
            i += 1
            A[i], A[j] = A[j], A[i]
    A[i+1], A[high] = A[high], A[i+1]
    return i+1

arr = [44,22,33,77,11,55,66]
print("Original array:", arr)
quick_sort(arr, 0, len(arr)-1)
print("Sorted array:", arr)
# Out:
# Original array:  [44, 22, 33, 77, 11, 55, 66]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 24
#      22 arr=[44,22,33,77,11,55,66]
#      23 print("Original array: ",arr)
# ---> 24 quick_sort(arr,0,len(arr)-1)
#      25 print("Sorted ARRAy: ",arr)
#
# Cell In[3], line 4, in quick_sort(A, low, high)
#       2 if low<high:
#       3     p = partition(A,low,high)
# ----> 4     quick_sort(A,low,p-1)
#       5     quick_sort(A,p+1, high)
#
# Cell In[3], line 3, in quick_sort(A, low, high)
#       1 def quick_sort(A,low,high):
#       2     if low<high:
# ----> 3         p = partition(A,low,high)
#       4         quick_sort(A,low,p-1)
#       5         quick_sort(A,p+1, high)
#
# Cell In[3], line 10, in partition(A, low, high)
#       8 x= low+1
#       9 y = high
# ---> 10 while x<=y:
#      11     while A[x]<=pivot and x<=high:
#      12         x = x+1
#
# KeyboardInterrupt:
